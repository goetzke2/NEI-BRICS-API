# %% [markdown]
# ### Creates a list of participants without genetics data in BRICS using API

# %%
import numpy as np
import pandas as pd
import requests # used to API calls
import json # used for creating json files
import getpass
from io import StringIO
import os
import datetime as dt
import time
import sys

# %%
def create_folder(folder_path):
    adjusted_folder_path = folder_path
    folder_found = os.path.isdir(adjusted_folder_path)
    counter = 0
    while folder_found == True:
        counter = counter + 1
        adjusted_folder_path = folder_path + ' (' + str(counter) + ')'
        folder_found = os.path.isdir(adjusted_folder_path)
    os.mkdir(adjusted_folder_path)
    return adjusted_folder_path

x=dt.datetime.now()
new_dir = os.getcwd()+'\\'+"EyeGene_"+x.strftime('%Y_%m_%d')+"_outputfiles"
created_dir = create_folder(new_dir)

# %%
## login
print("Enter your username")
username = input()

password = getpass.getpass("Enter your password")
# Out:
# Enter your username
# goetzke
# Enter your password········

# %%
#headers and payload for authentication
loginheaders = {
    'accept': 'text/plain',
    'Content-Type': 'application/x-www-form-urlencoded'
}

logindata = {'password':password,
         'username': username}

# %%
response = requests.post("https://bricsnei-stage.cit.nih.gov/gateway/authentication/user/login", headers=loginheaders, data=logindata)
#login in check 
if response.status_code == 200:
    print("Login Successful")
    token=response.text
    print(token)
elif response.status_code != 200:
    print(response.status_code)
    print("Login not Successful. Please check username and password. If error still occurs reach out to system adminstrator. THIS CODE WILL NOT PROCEED")
# Out:
# Login Successful
# eyJhbGciOiJIUzUxMiJ9..QRAudKVgSoqSL3nn4w5hLJkkBwSFdImeMkT-98kGBp4VoMDNORA88yVxp14aRtcXfIMMbFF_RHlp8JmSzRBYWQ

# %% [markdown]
# # Pull Genomics Data

# %%
url = "https://bricsnei-stage.cit.nih.gov/gateway/query-api/study/form?formName="

header = {
    'accept': 'application/json',
    'Content-type': 'application/json',
    'Authorization':'Bearer ' + token
}

formstructureshortname = input()
# Out:
# eyeGENEGenomics

# %%
query = requests.get(url + formstructureshortname, headers=header)

# %%
formstructureinformation = query.json()
formstructureinformation
# Out:
# [{'form': 'eyeGENEGenomics',
#   'studies': [{'abstract': 'The National Ophthalmic Disease Genotyping and Phenotyping Network (eyeGENE) is a research venture created by the National Eye Institute (NEI), part of the National Institutes of Health (NIH), in response to promising scientific discoveries in genetics. eyeGENE aims to advance studies of eye diseases and their genetic causes by giving researchers access to DNA samples, clinical information, and patients looking to participate in research studies and clinical trials. Contact Us: Phone: (301) 435-3032 Email: neieyegeneinfo@nei.nih.gov ',
#     'status': 'Public',
#     'id': 'EYEGENE-STUDY0000203',
#     'title': 'eyeGENE',
#     'pi': 'Kerry Goetz'},
#    {'abstract': 'Test Study 1',
#     'status': 'Private',
#     'id': 'NEI_BRICS-STUDY0000210',
#     'title': 'Test Study 1',
#     'pi': 'Alex Trudov'},
#    {'abstract': 'Repo Study Abstract Text',
#     'status': 'Public',
#     'id': 'NEI_BRICS-STUDY0000224',
# ...

# %%
formsurl = 'https://bricsnei-stage.cit.nih.gov/gateway/query-api/data/bulk/form/study'


formsheader = {
    'Content-type': 'application/json',
    'Authorization':'Bearer ' + token
}


'''

header = {
    'accept': 'application/json',
    'Content-type': 'application/json',
    'Authorization':'Bearer ' + token
}
'''
# Out:
# "\n\nheader = {\n    'accept': 'application/json',\n    'Content-type': 'application/json',\n    'Authorization':'Bearer ' + token\n}\n"

# %%
formsfilter = {
    "flattened":"false",
    "formStudies": [
        {
            "form": "eyeGENEGenomics",
            "studies": [
                "EYEGENE-STUDY0000203"
            ]
        },
        
    ],
    "outputFormat": "csv"
}

# %%
formsquery = requests.post(formsurl, headers = formsheader, json=formsfilter)
formsquery
# Out:
# <Response [200]>

# %%
genetics = pd.read_csv(r"C:\Users\goetzke\OneDrive - National Institutes of Health\Data Sets\gen 11-17-2020_2020-11-17T13-55-46\query_result_eyeGENEGenomics_2020-11-17T13-55-467561710107412328934.csv")
genetics
# Out:
#         Study ID                Dataset eyeGENEGenomics.Main.GUID  \
# 0            203  NEI_BRICS-DATA0000612           NEI_INVFP385NK9
# 1            203  NEI_BRICS-DATA0000612           NEI_INVNW297GV4
# 2            203  NEI_BRICS-DATA0000612           NEI_INVFP385NK9
# 3            203  NEI_BRICS-DATA0000612           NEI_INVRP581FPU
# 4            203  NEI_BRICS-DATA0000612           NEI_INVRP581FPU
# ...          ...                    ...                       ...
# 907156       203  NEI_BRICS-DATA0000612           NEI_INVLT070WKT
# 907157       203  NEI_BRICS-DATA0000612           NEI_INVTX906TT1
# 907158       203  NEI_BRICS-DATA0000612           NEI_INVFD057YCL
# 907159       203  NEI_BRICS-DATA0000612           NEI_INVRG494MCP
# 907160       203  NEI_BRICS-DATA0000612           NEI_INVDU729UAA
#
#         eyeGENEGenomics.Main.eyeGENEID  eyeGENEGenomics.Main.AgeYrs  \
# 0                                 1307                           38
# ...

# %%
#number of people tested
pplwith=genetics['eyeGENEGenomics.Main.eyeGENEID'].unique()
pplwith
# Out:
# array([1307, 4554, 4876, ..., 5735,  562, 2695], dtype=int64)

# %%
len(pplwith)
# Out:
# 5562

# %%
demo = pd.read_csv(r"C:\Users\goetzke\OneDrive - National Institutes of Health\Data Sets\11-17-2020 eG Demogr_2020-11-18T11-17-45\query_result_eyeGENEDemographics_2020-11-18T11-17-45679206811695540468.csv")
demo
# Out:
#       Study ID                Dataset eyeGENEDemographics.Main.GUID  \
# 0          203  NEI_BRICS-DATA0000606               NEI_INVPG793UHY
# 1          203  NEI_BRICS-DATA0000606               NEI_INVTD432XWJ
# 2          203  NEI_BRICS-DATA0000606               NEI_INVBP642WJ8
# 3          203  NEI_BRICS-DATA0000606               NEI_INVWL080YBF
# 4          203  NEI_BRICS-DATA0000606               NEI_INVLV841NV5
# ...        ...                    ...                           ...
# 6400       203  NEI_BRICS-DATA0000606               NEI_INVCX651JBF
# 6401       203  NEI_BRICS-DATA0000606               NEI_INVXT903APC
# 6402       203  NEI_BRICS-DATA0000606               NEI_INVGU132LBY
# 6403       203  NEI_BRICS-DATA0000606               NEI_INVRC186NHZ
# 6404       203  NEI_BRICS-DATA0000606               NEI_INVAU539AZH
#
#       eyeGENEDemographics.Main.eyeGENEID  eyeGENEDemographics.Main.AgeYrs  \
# 0                                   5507                               45
# ...

# %%
#number of people tested
ttlppl=demo['eyeGENEDemographics.Main.eyeGENEID'].unique()
ttlppl
# Out:
# array([5507, 3580, 5508, ..., 1097, 2033, 3730], dtype=int64)

# %%
len(ttlppl)
# Out:
# 6403

# %%
no_gen = []

for item in ttlppl:
    if item not in pplwith:
        no_gen.append(item)

print(no_gen)
# Out:
# [6280, 2939, 4947, 6282, 2938, 6283, 6284, 6285, 5927, 5928, 6287, 6288, 6289, 6290, 6292, 6293, 6294, 6295, 6296, 3578, 6254, 2231, 6256, 5932, 4941, 5933, 2956, 5934, 3574, 4940, 3571, 6262, 6264, 6266, 6261, 2941, 2944, 6268, 6270, 6273, 6274, 5512, 5509, 3179, 4919, 5952, 5953, 3554, 3550, 5526, 5525, 3549, 3171, 3548, 5918, 5920, 5921, 1648, 3583, 6276, 2940, 5923, 2937, 2936, 2930, 5924, 6277, 6278, 5543, 5547, 5975, 1638, 5940, 2976, 4549, 5942, 5943, 2964, 2963, 4925, 5949, 1660, 323, 1659, 4589, 4575, 5530, 5536, 5966, 3161, 5967, 5969, 4530, 5971, 5972, 1304, 5973, 1305, 5540, 1306, 5974, 1289, 1291, 638, 633, 6231, 6232, 6233, 605, 604, 6236, 6237, 636, 603, 6245, 6247, 6248, 6249, 6250, 609, 712, 4185, 4178, 4179, 6501, 4692, 5659, 5877, 5884, 5880, 5882, 5888, 2204, 5886, 5887, 5894, 3537, 5855, 5141, 5859, 648, 1951, 5860, 5861, 5136, 5863, 356, 1980, 6479, 357, 6477, 5865, 5281, 5866, 5867, 6407, 657, 661, 1822, 653, 5183, 5182, 342, 1674, 677, 1954, 1953, 4510, 4501, 
# ...

# %%
no_gen.sort()
no_gen
# Out:
# [25,
#  28,
#  29,
#  30,
#  40,
#  53,
#  54,
#  68,
#  118,
#  122,
#  123,
#  124,
#  130,
#  134,
#  137,
#  140,
#  148,
#  174,
#  180,
#  181,
#  190,
#  245,
#  255,
#  258,
#  260,
#  267,
#  278,
#  279,
#  323,
#  342,
#  356,
#  357,
#  396,
#  406,
#  409,
#  413,
#  427,
#  437,
#  454,
#  455,
#  467,
#  486,
#  506,
#  517,
#  521,
#  522,
#  530,
#  533,
#  535,
#  537,
#  547,
#  568,
#  603,
#  604,
#  605,
#  609,
#  633,
#  636,
#  638,
#  648,
#  653,
#  657,
#  661,
#  677,
#  712,
#  717,
#  725,
#  729,
#  732,
#  734,
#  735,
#  737,
#  745,
#  746,
#  747,
#  750,
#  759,
#  767,
#  768,
#  772,
#  775,
#  778,
#  780,
#  786,
#  792,
#  795,
#  797,
#  802,
#  818,
#  821,
#  830,
#  840,
#  847,
#  859,
#  863,
#  865,
#  880,
#  893,
#  894,
#  898,
#  900,
#  903,
#  905,
#  922,
#  928,
#  931,
#  944,
#  945,
#  947,
#  948,
#  977,
#  978,
#  979,
#  1029,
#  1030,
#  1031,
#  1048,
#  1049,
#  1063,
#  1078,
#  1079,
#  1080,
#  1082,
#  1092,
# ...

# %%
len(no_gen)
# Out:
# 841
